# %%
import pandas as pd
import numpy as np
from chainconsumer import Chain, ChainConsumer, Truth


values = np.load('./gradient_descent_optimistix_results.npz')['values']
numeric_df = pd.DataFrame(np.array(values), columns=["$M_{Plummer}$", "$M^{NFW}$", "$r^{NFW}_s$", "$t_{end}$"])

c = ChainConsumer()
c.add_chain(Chain(samples=numeric_df, name="Gradient descend", ), )

# c.add_truth(Truth(location = {"$M_{Plummer}$": params.Plummer_params.Mtot * code_units.code_mass.to(u.Msun),
#                               "$M^{NFW}$": params.NFW_params.Mvir * code_units.code_mass.to(u.Msun), 
#                               "$r^{NFW}_s$": params.NFW_params.r_s * code_units.code_length.to(u.kpc),
#                               "$t_{end}$": params.t_end * code_units.code_time.to(u.Gyr),
#                               }, color='red', name="True value"))
fig = c.plotter.plot()
# Out:
# /export/home/vgiusepp/miniconda3/envs/odisseo_sim/lib/python3.12/site-packages/numpy/lib/_histograms_impl.py:902: RuntimeWarning: invalid value encountered in divide
#   return n/db/n.sum(), bin_edges
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[12], line 17
#      10 c.add_chain(Chain(samples=numeric_df, name="Gradient descend", ), )
#      12 # c.add_truth(Truth(location = {"$M_{Plummer}$": params.Plummer_params.Mtot * code_units.code_mass.to(u.Msun),
#      13 #                               "$M^{NFW}$": params.NFW_params.Mvir * code_units.code_mass.to(u.Msun),
#      14 #                               "$r^{NFW}_s$": params.NFW_params.r_s * code_units.code_length.to(u.kpc),
#      15 #                               "$t_{end}$": params.t_end * code_units.code_time.to(u.Gyr),
#      16 #                               }, color='red', name="True value"))
# ---> 17 fig = c.plotter.plot()
#
# File ~/miniconda3/envs/odisseo_sim/lib/python3.12/site-packages/chainconsumer/plotter.py:203, in Plotter.plot(self, chains, columns, filename, figsize)
#     200     continue
#     202 do_summary = summarise and p1 not in base.blind
# --> 203 max_hist_val = self._plot_bars(ax, p1, chain, flip=do_flip, summary=do_summary)
#     205 if max_val is None or max_hist_val > max_val:
#     206     max_val = max_hist_val
#
# File ~/miniconda3/envs/odisseo_sim/lib/python3.12/site-packages/chainconsumer/plotter.py:944, in Plotter._plot_bars(self, ax, column, chain, flip, summary)
#     941 interpolator = interp1d(xs, ys, kind=interp_type)
#     943 if chain.bar_shade:
# --> 944     fit_values = self.parent.analysis.get_parameter_summary(chain, column)
#     945     if fit_values is not None:
#     946         lower = fit_values.lower
#
# File ~/miniconda3/envs/odisseo_sim/lib/python3.12/site-packages/chainconsumer/analysis.py:218, in Analysis.get_parameter_summary(self, chain, column)
#     216 def get_parameter_summary(self, chain: Chain, column: ColumnName) -> Bound | None:
#     217     callback = self._summaries[chain.statistics]
# --> 218     return callback(chain, column)
#
# File ~/miniconda3/envs/odisseo_sim/lib/python3.12/site-packages/chainconsumer/analysis.py:439, in Analysis.get_parameter_summary_max(self, chain, column)
#     437 if count > 50:
#     438     raise ValueError("Failed to converge")  # noqa: TRY301
# --> 439 i1 = start_index - np.where(ys[:start_index][::-1] < mid)[0][0]
#     440 i2 = start_index + np.where(ys[start_index:] < mid)[0][0]
#     441 area = cs[i2] - cs[i1]
#
# IndexError: index 0 is out of bounds for axis 0 with size 0

# %%
import corner

corner.corner(numeric_df, show_titles=True)
# Out:
# WARNING:root:Pandas support in corner is deprecated; use ArviZ directly
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
