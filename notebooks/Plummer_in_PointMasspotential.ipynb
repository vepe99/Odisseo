# %%
import os
from math import pi

# os.environ["CUDA_VISIBLE_DEVICES"] = "0"  # Use only the first GPU
from typing import Optional, Tuple, Callable, Union, List
from functools import partial

import matplotlib.pyplot as plt
import jax
import jax.numpy as jnp
from jax import vmap, jit
from jax import random
jax.config.update("jax_enable_x64", True)

import numpy as np
from astropy import units as u
from astropy import constants as c

import jdgsim
from jdgsim import construct_initial_state
from jdgsim.integrators import leapfrog
from jdgsim.dynamics import direct_acc, DIRECT_ACC_LAXMAP
from jdgsim.option_classes import SimulationConfig, SimulationParams, PointMassParams, PlummerParams, POINT_MASS
from jdgsim.initial_condition import Plummer_sphere, ic_two_body
from jdgsim.utils import center_of_mass
from jdgsim.time_integration import time_integration
from jdgsim.units import CodeUnits
from jdgsim.visualization import create_3d_gif, create_3d_gif_velocitycoding, create_projection_gif


plt.rcParams.update({
    'font.size': 20,
    'axes.labelsize': 20,
    'xtick.labelsize': 13,
    'ytick.labelsize': 13,
    'legend.fontsize': 15,
})

# %% [markdown]
# # Plummer Sphere

# %%
code_length = 10.0 * u.kpc
code_mass = 1e8 * u.Msun
G = 1 
code_units = CodeUnits(code_length, code_mass, G=G)

# %%
# Define the 
config = SimulationConfig(N_particles=100_000, 
                          return_snapshots=True, 
                          num_snapshots=50, 
                          num_timesteps=1_00, 
                          external_accelerations=(POINT_MASS,  ), 
                        #   acceleration_scheme=DIRECT_ACC_LAXMAP,
                          softening=1e-10) #default values

params = SimulationParams(t_end = (10 * u.Gyr).to(code_units.code_time).value,  
                          Plummer_params= PlummerParams(Mtot=(1e8 * u.Msun).to(code_units.code_mass).value,
                                                        a=(1 * u.kpc).to(code_units.code_length).value),
                          PointMass_params= PointMassParams(M=(1e12 * u.Msun).to(code_units.code_mass).value),
                          G=G, ) 

print(config)
print(params)
# Out:
# SimulationConfig(N_particles=100000, dimensions=3, return_snapshots=True, num_snapshots=50, fixed_timestep=True, num_timesteps=100, softening=1e-10, integrator=0, acceleration_scheme=0, batch_size=10000, external_accelerations=(1,))
# SimulationParams(G=1, t_end=6.7070874092034565, NFW_params=NFWParams(Mvir=<Quantity 1.62e+11 solMass>, r_s=<Quantity 15.3 kpc>, c=10, d_c=1.4888043637074615), Plummer_params=PlummerParams(a=0.1, Mtot=1.0), PointMass_params=PointMassParams(M=10000.0))

# %%
#set up the particles in the initial state
positions, velocities, mass = Plummer_sphere(key=random.PRNGKey(0), params=params, config=config)

#Plummer sphere distribution
fig = plt.figure(figsize=(15, 5))
ax = fig.add_subplot(121)
ax.hist((jnp.linalg.norm(positions, axis=1) * code_units.code_length).to(u.kpc), bins=100, histtype='step', color='k')
ax.axvline((params.Plummer_params.a*code_units.code_length).to(u.kpc).value, color='r', label='Plummer a')
ax.set_xlabel('R [kpc]')

ax = fig.add_subplot(122)
ax.hist(jnp.linalg.norm((velocities * code_units.code_velocity).to(u.km/u.s).value, axis=1), bins=100, histtype='step', color='k')
ax.set_xlabel('v [km/s]')
plt.show()

# %%
#put the Plummer sphere in a ciruclar orbit around the NFW halo
rp=200*u.kpc.to(code_units.code_length)

if len(config.external_accelerations)>0:
    pos, vel, _ = ic_two_body(params.PointMass_params.M, params.Plummer_params.Mtot, rp=rp, e=0., config=config, params=params)
    velocities = velocities + vel[1]
    positions = positions + pos[1]

#initialize the initial state
initial_state = construct_initial_state(positions, velocities)

# %%
if config.return_snapshots: 
    snapshots = time_integration(initial_state, mass, config, params)
else:
    final_state = time_integration(initial_state, mass, config, params)
# Out:
# /export/home/vgiusepp/miniconda3/envs/test_sstrax/lib/python3.12/site-packages/jax/_src/core.py:700: FutureWarning: unhashable type: <class 'jax._src.interpreters.partial_eval.DynamicJaxprTracer'>. Attempting to hash a tracer will lead to an error in a future JAX release.
#   warnings.warn(
# /export/home/vgiusepp/miniconda3/envs/test_sstrax/lib/python3.12/site-packages/jax/_src/core.py:700: FutureWarning: unhashable type: <class 'jax._src.interpreters.partial_eval.DynamicJaxprTracer'>. Attempting to hash a tracer will lead to an error in a future JAX release.
#   warnings.warn(
# 2025-03-03 11:15:43.120772: W external/xla/xla/hlo/transforms/simplifiers/hlo_rematerialization.cc:3020] Can't reduce memory use below 27.85GiB (29904597853 bytes) by rematerialization; only reduced to 75.30GiB (80855202232 bytes), down from 75.30GiB (80855202232 bytes) originally
# 2025-03-03 11:15:53.686771: W external/xla/xla/tsl/framework/bfc_allocator.cc:497] Allocator (GPU_0_bfc) ran out of memory trying to allocate 75.07GiB (rounded to 80610401792)requested by op
# 2025-03-03 11:15:53.687015: W external/xla/xla/tsl/framework/bfc_allocator.cc:508] **__________________________________________________________________________________________________
# E0303 11:15:53.687060 4100507 pjrt_stream_executor_client.cc:3085] Execution of replica 0 failed: RESOURCE_EXHAUSTED: Out of memory while trying to allocate 80610401632 bytes.
# ---------------------------------------------------------------------------
# XlaRuntimeError                           Traceback (most recent call last)
# Cell In[19], line 2
#       1 if config.return_snapshots:
# ----> 2     snapshots = time_integration(initial_state, mass, config, params)
#       3 else:
#       4     final_state = time_integration(initial_state, mass, config, params)
#
#     [... skipping hidden 10 frame]
#
# File ~/miniconda3/envs/test_sstrax/lib/python3.12/site-packages/jax/_src/interpreters/pxla.py:1287, in ExecuteReplicated.__call__(self, *args)
#    1285   self._handle_token_bufs(result_token_bufs, sharded_runtime_token)
#    1286 else:
# -> 1287   results = self.xla_executable.execute_sharded(input_bufs)
#    1289 if dispatch.needs_check_special():
#    1290   out_arrays = results.disassemble_into_single_device_arrays()
#
# XlaRuntimeError: RESOURCE_EXHAUSTED: Out of memory while trying to allocate 80610401632 bytes.

# %%
fig = plt.figure(figsize=(10, 10),) 
ax = fig.add_subplot(111, projection='3d')

# Normalize the times to the range [0, 1] for colormap
times = (snapshots.times * code_units.code_time).to(u.Gyr)
norm_times = (times - times.min()) / (times.max() - times.min())

# Generate colors using a colormap
cmap = plt.get_cmap('viridis')
colors = cmap(norm_times)
for i in range(0, len(snapshots.states), 10):
    sc = ax.scatter((snapshots.states[i, :, 0, 0] * code_units.code_length).to(u.kpc).value, 
                    (snapshots.states[i, :, 0, 1] * code_units.code_length).to(u.kpc).value,
                    (snapshots.states[i, :, 0, 2] * code_units.code_length).to(u.kpc).value,
                    color=colors[i])

ax.scatter(0, 0, 0, c='r', s=100)
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')


cbar = plt.colorbar(sc, location='top')
cbar.set_label('Simulation percentage')
plt.legend()
# Out:
# /tmp/ipykernel_4100507/3655089278.py:25: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
fig = plt.figure(figsize=(17, 5))
ax = fig.add_subplot(121)
Delta_E = ((snapshots.total_energy - snapshots.total_energy[0])/snapshots.total_energy[0])
ax.plot((snapshots.times * code_units.code_time).to(u.Gyr), Delta_E,)
ax.set_xlabel('Time [Gyr]')
ax.set_ylabel(r'$(E - E_0)/E_0$')
ax.set_ylim(-1, 1)
ax.grid(linestyle='dotted')

ax = fig.add_subplot(122)
Delta_AngMom = ((snapshots.angular_momentum - snapshots.angular_momentum[0])/snapshots.angular_momentum[0])
ax.plot((snapshots.times * code_units.code_time).to(u.Gyr), Delta_AngMom[:, 2], )
ax.set_xlabel('Time [Gyr]')
ax.set_ylabel(r'$(L - L_0)/L_0$')
ax.set_ylim(-1, 1)
ax.grid(linestyle='dotted')

# %%
create_3d_gif(snapshots, 
              ax_lim=rp, 
              code_units=code_units, 
              plotting_units_length=u.kpc, 
              plot_units_time=u.Gyr, 
              filename='simulation_Plummer_in_PointMasspotential.gif')

# %%
create_3d_gif_velocitycoding(snapshots, 
                            ax_lim=rp, 
                            code_units=code_units, 
                            plotting_units_length=u.kpc, 
                            plot_units_time=u.Gyr, 
                            filename='simulation_Plummer_in_PointMasspotential_velocitycoding.gif')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 create_3d_gif_velocitycoding(snapshots,
#       2                             ax_lim=rp,
#       3                             code_units=code_units,
#       4                             plotting_units_length=u.kpc,
#       5                             plot_units_time=u.Gyr,
#       6                             filename='simulation_Plummer_in_PointMasspotential_velocitycoding.gif')
#
# File ~/jdgsim/jdgsim/visualization.py:107, in create_3d_gif_velocitycoding(snapshots, ax_lim, code_units, plotting_units_length, plot_units_time, vmin, vmax, filename)
#     103 anim = FuncAnimation(fig, update, frames=range(0, len(snapshots.states), 1), init_func=init, blit=False)
#     105 if filename is not None:
#     106     # Save the animation as a GIF
# --> 107     anim.save(filename, writer=PillowWriter(fps=10))
#
# File ~/miniconda3/envs/test_sstrax/lib/python3.12/site-packages/matplotlib/animation.py:1085, in Animation.save(self, filename, writer, fps, dpi, codec, bitrate, extra_args, metadata, extra_anim, savefig_kwargs, progress_callback)
#    1082 for data in zip(*[a.new_saved_frame_seq() for a in all_anim]):
#    1083     for anim, d in zip(all_anim, data):
#    1084         # TODO: See if turning off blit is really necessary
# -> 1085         anim._draw_next_frame(d, blit=False)
#    1086         if progress_callback is not None:
#    1087             progress_callback(frame_number, total_frames)
#
# File ~/miniconda3/envs/test_sstrax/lib/python3.12/site-packages/matplotlib/animation.py:1120, in Animation._draw_next_frame(self, framedata, blit)
#    1116 def _draw_next_frame(self, framedata, blit):
#    1117     # Breaks down the drawing of the next frame into steps of pre- and
#    1118     # post- draw, as well as the drawing of the frame itself.
#    1119     self._pre_draw(framedata, blit)
# -> 1120     self._draw_frame(framedata)
#    1121     self._post_draw(framedata, blit)
#
# File ~/miniconda3/envs/test_sstrax/lib/python3.12/site-packages/matplotlib/animation.py:1746, in FuncAnimation._draw_frame(self, framedata)
#    1742     self._save_seq = self._save_seq[-self._save_count:]
#    1744 # Call the func with framedata and args. If blitting is desired,
#    1745 # func needs to return a sequence of any artists that were modified.
# -> 1746 self._drawn_artists = self._func(framedata, *self._args)
#    1748 if self._blit:
#    1750     err = RuntimeError('The animation function must return a sequence '
#    1751                        'of Artist objects.')
#
# File ~/jdgsim/jdgsim/visualization.py:95, in create_3d_gif_velocitycoding.<locals>.update(frame)
#      92 scatter2 = ax.scatter(0, 0, 0, c='r', s=100, marker='*')
#      94 if cbar is not None:
# ---> 95     cbar.remove()
#      96 cbar = fig.colorbar(scatter1, ax=ax, shrink=0.8, pad=0.1)
#      97 # vel_label = f"Velocity" if code_units.velocity_units is None else f"Velocity [{code_units.velocity_units}]"
#      98 # cbar.set_label(vel_label)
#
# File ~/miniconda3/envs/test_sstrax/lib/python3.12/site-packages/matplotlib/colorbar.py:1040, in Colorbar.remove(self)
#    1038     ax._set_position(pos)
#    1039 else:  # use_gridspec was True
# -> 1040     ax.set_subplotspec(subplotspec)
#
# AttributeError: 'NoneType' object has no attribute 'set_subplotspec'

# %%
create_projection_gif(snapshots=snapshots,
                      ax_lim=rp, 
                      code_units=code_units, 
                      plotting_units_length=u.kpc, 
                      plot_units_time=u.Gyr, 
                      filename='simulation_projection_Plummer_in_PointMasspotential.gif')
